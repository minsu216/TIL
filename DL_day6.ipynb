# 2014-09-21  4.161897e+05     27737663355
# ...                  ...             ...
# 2023-11-03  4.661862e+07  28018157917905
# 2023-11-04  4.546514e+07  22460677199165
# 2023-11-05  4.592312e+07  12515877610681
# 2023-11-06  4.587688e+07  16247317395243
# 2023-11-07  4.579245e+07  17088699695104
#
# [3339 rows x 6 columns]

# %%
kakao.index
# Out:
# DatetimeIndex(['1999-11-11', '1999-11-12', '1999-11-15', '1999-11-16',
#                '1999-11-17', '1999-11-18', '1999-11-19', '1999-11-22',
#                '1999-11-23', '1999-11-24',
#                ...
#                '2023-10-25', '2023-10-26', '2023-10-27', '2023-10-30',
#                '2023-10-31', '2023-11-01', '2023-11-02', '2023-11-03',
#                '2023-11-06', '2023-11-07'],
#               dtype='datetime64[ns]', name='Date', length=5921, freq=None)

# %%
kakao['year']=kakao.index.year
kakao['month']=kakao.index.month
kakao['day']=kakao.index.day

# %%
kakao
# Out:
#              Open   High    Low  Close   Volume    Change  year  month  day
# Date
# 1999-11-11    999    999    999    999       12       NaN  1999     11   11
# 1999-11-12   1115   1115   1115   1115      140  0.116116  1999     11   12
# 1999-11-15   1249   1249   1249   1249      405  0.120179  1999     11   15
# 1999-11-16   1396   1396   1396   1396      214  0.117694  1999     11   16
# 1999-11-17   1561   1561   1561   1561      191  0.118195  1999     11   17
# ...           ...    ...    ...    ...      ...       ...   ...    ...  ...
# 2023-11-01  38000  38300  37450  37600  1272093 -0.005291  2023     11    1
# 2023-11-02  38000  38600  37900  38550  1529650  0.025266  2023     11    2
# 2023-11-03  39250  41550  38900  41300  3675484  0.071336  2023     11    3
# 2023-11-06  43000  44700  42300  44700  4871031  0.082324  2023     11    6
# 2023-11-07  44700  44750  42850  43750  2019068 -0.021253  2023     11    7
#
# [5921 rows x 9 columns]

# %%
plt.figure(figsize=(16,9))
sns.lineplot(y=kakao['Close'], x=kakao.index)
plt.xlabel('time')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
ts=[['2000', '2010'],
    ['2010', '2015'],
    ['2015', '2020'],
    ['2020', '2023']]

# %%
fig, axes=plt.subplots(2,2)
fig.set_size_inches(16,9)
for i in range(4):
    ax = axes[i//2, i%2]
    df = kakao.loc[(kakao.index > ts[i][0]) & (kakao.index <ts[i][1])]
    sns.lineplot(y=df['Close'], x=df.index, ax=ax)
    ax.set_title(f'{ts[i][0]}~{ts[i][1]}')
    ax.set_xlabel('time')
    ax.set_ylabel('price')
plt.tight_layout()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
cols = ['Open', 'High', 'Low', 'Close', 'Volume']

# %%
scaled=scaler.fit_transform(kakao[cols])
scaled
# Out:
# array([[5.80813953e-03, 5.77456647e-03, 6.20496894e-03, 0.00000000e+00,
#         6.35083673e-07],
#        [6.48255814e-03, 6.44508671e-03, 6.92546584e-03, 6.88423214e-04,
#         7.40930952e-06],
#        [7.26162791e-03, 7.21965318e-03, 7.75776398e-03, 1.48367072e-03,
#         2.14340740e-05],
#        ...,
#        [2.28197674e-01, 2.40173410e-01, 2.41614907e-01, 2.39173655e-01,
#         1.94519990e-01],
#        [2.50000000e-01, 2.58381503e-01, 2.62732919e-01, 2.59351577e-01,
#         2.57792688e-01],
#        [2.59883721e-01, 2.58670520e-01, 2.66149068e-01, 2.53713628e-01,
#         1.06856427e-01]])

# %%
df = pd.DataFrame(scaled, columns=cols)

# %%
df
# Out:
#           Open      High       Low     Close        Volume
# 0     0.005808  0.005775  0.006205  0.000000  6.350837e-07
# 1     0.006483  0.006445  0.006925  0.000688  7.409310e-06
# 2     0.007262  0.007220  0.007758  0.001484  2.143407e-05
# 3     0.008116  0.008069  0.008671  0.002356  1.132566e-05
# 4     0.009076  0.009023  0.009696  0.003335  1.010842e-05
# ...        ...       ...       ...       ...           ...
# 5916  0.220930  0.221387  0.232609  0.217215  6.732379e-02
# 5917  0.220930  0.223121  0.235404  0.222853  8.095465e-02
# 5918  0.228198  0.240173  0.241615  0.239174  1.945200e-01
# 5919  0.250000  0.258382  0.262733  0.259352  2.577927e-01
# 5920  0.259884  0.258671  0.266149  0.253714  1.068564e-01
#
# [5921 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest=train_test_split(df.drop('Close',1), df['Close'], test_size=0.2, random_state=0, shuffle=False )
# Out:
# <ipython-input-102-c1a12691dd21>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   xtrain, xtest, ytrain, ytest=train_test_split(df.drop('Close',1), df['Close'], test_size=0.2, random_state=0, shuffle=False )

# %%
xtrain.shape
# Out:
# (4736, 4)

# %%
xtest.shape
# Out:
# (1185, 4)

# %%
ytrain.shape
# Out:
# (4736,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN

model = Sequential()
model.add(SimpleRNN(3, input_shape=(2,10)))
# model.add(SimpleRNN(3, input_length=2, input_dim=10))와 동일함.
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 3)                 42
#
# =================================================================
# Total params: 42 (168.00 Byte)
# Trainable params: 42 (168.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import numpy as np

timesteps = 10
input_dim = 4
hidden_units = 8

# 입력에 해당되는 2D 텐서
inputs = np.random.random((timesteps, input_dim))

# %%
inputs
# Out:
# array([[0.2421058 , 0.13370795, 0.22637054, 0.79701938],
#        [0.58230623, 0.25465955, 0.68775671, 0.22994778],
#        [0.12587117, 0.22169309, 0.51273247, 0.27423668],
#        [0.11172423, 0.24584777, 0.90459192, 0.67339111],
#        [0.36026453, 0.23319061, 0.00475004, 0.81227863],
#        [0.87269769, 0.85891804, 0.56922009, 0.43402149],
#        [0.24834128, 0.01184034, 0.80963905, 0.73015425],
#        [0.14167898, 0.48076677, 0.04127187, 0.2546111 ],
#        [0.17136362, 0.97158762, 0.41665796, 0.71719522],
#        [0.67158298, 0.53996468, 0.59754741, 0.63818227]])

# %%
# 초기 은닉 상태는 0(벡터)로 초기화
hidden_state_t = np.zeros((hidden_units,))
hidden_state_t
# Out:
# array([0., 0., 0., 0., 0., 0., 0., 0.])

# %%
print('초기 은닉 상태 :',hidden_state_t)
# Out:
# 초기 은닉 상태 : [0. 0. 0. 0. 0. 0. 0. 0.]

# %%
Wx = np.random.random((hidden_units, input_dim))  # (8, 4)크기의 2D 텐서 생성. 입력에 대한 가중치.
Wh = np.random.random((hidden_units, hidden_units)) # (8, 8)크기의 2D 텐서 생성. 은닉 상태에 대한 가중치.
b = np.random.random((hidden_units,)) # (8,)크기의 1D 텐서 생성. 이 값은 편향(bias).

print('가중치 Wx의 크기(shape) :',np.shape(Wx))
print('가중치 Wh의 크기(shape) :',np.shape(Wh))
print('편향의 크기(shape) :',np.shape(b))
# Out:
# 가중치 Wx의 크기(shape) : (8, 4)
# 가중치 Wh의 크기(shape) : (8, 8)
# 편향의 크기(shape) : (8,)

# %%
"""
timesteps = 10
input_dim = 4
hidden_units = 8
"""
# Out:
# '\ntimesteps = 10\ninput_dim = 4\nhidden_units = 8\n'

# %%
#RNN
import numpy as np

# %%
type(xtrain)
# Out:
# numpy.ndarray

# %%
def make_dataset(data, label, window_size=20):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
xtrain, ytrain = make_dataset(xtrain, ytrain, 20)

# %%
xtrain.shape
xtrain
# Out:
# array([[[5.80813953e-03, 5.77456647e-03, 6.20496894e-03, 6.35083673e-07],
#         [6.48255814e-03, 6.44508671e-03, 6.92546584e-03, 7.40930952e-06],
#         [7.26162791e-03, 7.21965318e-03, 7.75776398e-03, 2.14340740e-05],
#         ...,
#         [3.92151163e-02, 3.89884393e-02, 4.18944099e-02, 1.20612974e-04],
#         [4.38837209e-02, 4.36300578e-02, 4.68819876e-02, 9.83321221e-05],
#         [4.91279070e-02, 4.88439306e-02, 5.24844720e-02, 2.80495289e-05]],
#
#        [[6.48255814e-03, 6.44508671e-03, 6.92546584e-03, 7.40930952e-06],
#         [7.26162791e-03, 7.21965318e-03, 7.75776398e-03, 2.14340740e-05],
#         [8.11627907e-03, 8.06936416e-03, 8.67080745e-03, 1.13256588e-05],
#         ...,
#         [4.38837209e-02, 4.36300578e-02, 4.68819876e-02, 9.83321221e-05],
#         [4.91279070e-02, 4.88439306e-02, 5.24844720e-02, 2.80495289e-05],
#         [5.49883721e-02, 5.46705202e-02, 5.87453416e-02, 1.60358628e-05]],
#
#        [[7.26162791e-03, 7.21965318e-03, 7.75776398e-03, 2.14340740e-05],
#         [8.11627907e-03, 8.06936416e-03, 8.67080745e-03, 1.13256588e-05],
#         [9.07558140e-03, 9.02312139e-03, 9.69565217e-03, 1.01084151e-05],
#         ...,
#         [4.91279070e-02, 4.88439306e-02, 5.24844720e-02, 2.80495289e-05],
#         [5.49883721e-02, 5.46705202e-02, 5.87453416e-02, 1.60358628e-05],
#         [6.14709302e-02, 6.11156069e-02, 6.56708075e-02, 4.86368246e-05]],
#
#        ...,
#
#        [[1.30104651e-01, 1.32832370e-01, 1.37751553e-01, 2.61912212e-02],
#         [1.28936047e-01, 1.29346821e-01, 1.35881988e-01, 1.04155310e-02],
#         [1.28360465e-01, 1.29942197e-01, 1.35260870e-01, 9.16399279e-03],
#         ...,
#         [1.17860465e-01, 1.19497110e-01, 1.25291925e-01, 1.54311043e-02],
#         [1.17860465e-01, 1.20080925e-01, 1.25913043e-01, 9.55594526e-03],
#         [1.19017442e-01, 1.18329480e-01, 1.24409938e-01, 1.28765861e-02]],
#
#        [[1.28936047e-01, 1.29346821e-01, 1.35881988e-01, 1.04155310e-02],
#         [1.28360465e-01, 1.29942197e-01, 1.35260870e-01, 9.16399279e-03],
#         [1.26604651e-01, 1.28768786e-01, 1.33385093e-01, 1.00006097e-02],
#         ...,
#         [1.17860465e-01, 1.20080925e-01, 1.25913043e-01, 9.55594526e-03],
#         [1.19017442e-01, 1.18329480e-01, 1.24409938e-01, 1.28765861e-02],
#         [1.16680233e-01, 1.18907514e-01, 1.24037267e-01, 2.01946553e-02]],
#
#        [[1.28360465e-01, 1.29942197e-01, 1.35260870e-01, 9.16399279e-03],
#         [1.26604651e-01, 1.28768786e-01, 1.33385093e-01, 1.00006097e-02],
#         [1.26610465e-01, 1.26462428e-01, 1.32142857e-01, 1.15636564e-02],
#         ...,
#         [1.19017442e-01, 1.18329480e-01, 1.24409938e-01, 1.28765861e-02],
#         [1.16680233e-01, 1.18907514e-01, 1.24037267e-01, 2.01946553e-02],
#         [1.17267442e-01, 1.17167630e-01, 1.24409938e-01, 1.14954908e-02]]])

# %%
ytrain.shape
ytrain= ytrain.reshape(ytrain.shape[0],1)

# %%
ytrain.shape
# Out:
# (4716, 1)

# %%
xtest.shape
# Out:
# (1185, 4)

# %%
ytest.shape
# Out:
# (1185,)

# %%
xtest , ytest =make_dataset(xtest , ytest, 20 )

# %%
xtest.shape
# Out:
# (1165, 20, 4)

# %%
ytest.shape
ytest = ytest.reshape(ytest.shape[0],1)

# %%
ytest.shape
# Out:
# (1165, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM

from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM

# %%
model = Sequential()

# %%
model.add(LSTM(16, input_shape=(xtrain.shape[1], xtrain.shape[2]),
           activation='relu',
           return_sequences=False))

# %%
model.add(Dense(1)) # activation = linear (default)

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
early_stop = EarlyStopping(monitor='val_loss', patience=5)
checkpoint = ModelCheckpoint('tmp_checkpoint.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

# %%
xtrain, x_valid, ytrain, y_valid = train_test_split(xtrain, ytrain, test_size=0.2)

# %%
ytrain.shape
# Out:
# (3772, 1)

# %%
history = model.fit(xtrain, ytrain,
                    epochs=200,
                    batch_size=16,
                    validation_data=(x_valid, y_valid),
                    callbacks=[early_stop, checkpoint])
# Out:
# Epoch 1/200
# 235/236 [============================>.] - ETA: 0s - loss: 5.9747e-04
# Epoch 1: val_loss improved from inf to 0.00010, saving model to tmp_checkpoint.h5
# 236/236 [==============================] - 5s 12ms/step - loss: 5.9571e-04 - val_loss: 9.6283e-05
# Epoch 2/200
#  20/236 [=>............................] - ETA: 1s - loss: 7.0356e-05
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 235/236 [============================>.] - ETA: 0s - loss: 1.0275e-04
# Epoch 2: val_loss improved from 0.00010 to 0.00007, saving model to tmp_checkpoint.h5
# 236/236 [==============================] - 3s 13ms/step - loss: 1.0266e-04 - val_loss: 7.0933e-05
# Epoch 3/200
# 234/236 [============================>.] - ETA: 0s - loss: 7.9086e-05
# Epoch 3: val_loss did not improve from 0.00007
# 236/236 [==============================] - 3s 12ms/step - loss: 8.1508e-05 - val_loss: 7.1097e-05
# Epoch 4/200
# 233/236 [============================>.] - ETA: 0s - loss: 7.3757e-05
# Epoch 4: val_loss improved from 0.00007 to 0.00006, saving model to tmp_checkpoint.h5
# 236/236 [==============================] - 3s
val_loss improved from 0.00002 to 0.00002, saving model to tmp_checkpoint.h5
# 236/236 [==============================] - 3s 11ms/step - loss: 2.3118e-05 - val_loss: 2.1319e-05
# Epoch 46/200
# 236/236 [==============================] - ETA: 0s - loss: 2.1856e-05
# Epoch 46: val_loss improved from 0.00002 to 0.00002, saving model to tmp_checkpoint.h5
# 236/236 [==============================] - 3s 13ms/step - loss: 2.1856e-05 - val_loss: 2.1262e-05
# Epoch 47/200
# 233/236 [============================>.] - ETA: 0s - loss: 2.1926e-05
# Epoch 47: val_loss did not improve from 0.00002
# 236/236 [==============================] - 3s 15ms/step - loss: 2.2202e-05 - val_loss: 2.1663e-05
# Epoch 48/200
# 236/236 [==============================] - ETA: 0s - loss: 2.1658e-05
# Epoch 48: val_loss improved from 0.00002 to 0.00002, saving model to tmp_checkpoint.h5
# 236/236 [==============================] - 2s 9ms/step - loss: 2.1658e-05 - val_loss: 2.0982e-05
# Epoch 49/200
# 235/236 [============================>.] - ETA: 0s - loss: 2.1977e-05
# Epoch 49: val_loss improved from 0.00002 to 0.00002, saving model to tmp_checkpoint.h5
# 236/236 [==============================] - 3s 12ms/step - loss: 2.1937e-05 - val_loss: 2.0472e-05
# Epoch 50/200
# 233/236 [============================>.] - ETA: 0s - loss: 2.2355e-05
# Epoch 50: val_loss did not improve from 0.00002
# 236/236 [==============================] - 3s 12ms/step - loss: 2.2344e-05 - val_loss: 2.2005e-05
# Epoch 51/200
# 235/236 [============================>.] - ETA: 0s - loss: 2.1551e-05
# Epoch 51: val_loss improved from 0.00002 to 0.00002, saving model to tmp_checkpoint.h5
# 236/236 [==============================] - 4s 15ms/step - loss: 2.1558e-05 - val_loss: 2.0374e-05
# Epoch 52/200
# 233/236 [============================>.] - ETA: 0s - loss: 2.1274e-05
# Epoch 52: val_loss did not improve from 0.00002
# 236/236 [==============================] - 3s 15ms/step - loss: 2.1157e-05 - val_loss: 2.1488e-05
# Epoch 53/200
# 232/236 [============================>.] - ETA: 0s - loss: 2.1392e-05
# Epoch 53: val_loss did not improve from 0.00002
# 236/236 [==============================] - 2s 10ms/step - loss: 2.1345e-05 - val_loss: 2.0461e-05
# Epoch 54/200
# 232/236 [============================>.] - ETA: 0s - loss: 2.1178e-05
# Epoch 54: val_loss did not improve from 0.00002
# 236/236 [==============================] - 2s 10ms/step - loss: 2.1119e-05 - val_loss: 2.1573e-05
# Epoch 55/200
# 236/236 [==============================] - ETA: 0s - loss: 2.1076e-05
# Epoch 55: val_loss did not improve from 0.00002
# 236/236 [==============================] - 3s 11ms/step - loss: 2.1076e-05 - val_loss: 2.2802e-05
# Epoch 56/200
# 232/236 [============================>.] - ETA: 0s - loss: 2.0815e-05
# Epoch 56: val_loss did not improve from 0.00002
# 236/236 [==============================] - 3s 13ms/step - loss: 2.0663e-05 - val_loss: 2.0837e-05

# %%
model.load_weights('tmp_checkpoint.h5')
pred=model.predict(xtest)
# Out:
# 37/37 [==============================] - 0s 4ms/step

# %%
plt.figure(figsize=(12, 9))
plt.plot(ytest, label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.show()

# %%
pred.shape
# Out:
# (1165, 16)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-4101063b4ce7> in <cell line: 1>()
# ----> 1 scaler.inverse_trainsform(pred[0])
#
# AttributeError: 'MinMaxScaler' object has no attribute 'inverse_trainsform'
